# %%
from dotenv import load_dotenv

from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.agent.workflow import FunctionAgent
from llama_index.llms.openai import OpenAI


# Create a RAG tool using LlamaIndex
documents = SimpleDirectoryReader("data").load_data()
index = VectorStoreIndex.from_documents(documents)
query_engine = index.as_query_engine()


# Define a simple calculator tool
def multiply(a: float, b: float) -> float:
    """Useful for multiplying two numbers."""
    return a * b

async def search_documents(query: str) -> str:
    """Useful for answering natural language questions about an personal essay written by Paul Graham."""
    response = await query_engine.aquery(query)
    return str(response)



load_dotenv()


# Create an agent workflow with our calculator tool
agent = FunctionAgent(
    tools=[multiply, search_documents],
    llm=OpenAI(model="gpt-4o-mini"),
    system_prompt="""You are a helpful assistant that can perform calculations
    and search through documents to answer questions.""",
)

# Run the agent
response = await agent.run(
        "What did the author do in college? Also, what's 7 * 8?"
    )
print(str(response))
# Out:
# 2026-03-12 16:32:44,824 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-03-12 16:32:48,138 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-12 16:32:48,358 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-03-12 16:32:49,939 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-12 16:32:52,090 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# In college, the author initially planned to study philosophy but found the courses boring and switched to studying AI.
#
# As for the multiplication, \(7 \times 8 = 56\).

# %%
from llama_index.core.workflow import Context

# create context
ctx = Context(agent)

# run agent with context
response1 = await agent.run("My name is Logan", ctx=ctx)
response2 = await agent.run("What is my name?", ctx=ctx)

# %%
print(str(response1))
print(str(response2))
# Out:
# Nice to meet you, Logan! How can I assist you today?
# Your name is Logan.

# %%
# Save the index
index.storage_context.persist("storage")

# Later, load the index
from llama_index.core import StorageContext, load_index_from_storage

storage_context = StorageContext.from_defaults(persist_dir="storage")
index = load_index_from_storage(storage_context)
query_engine = index.as_query_engine()

# Run the agent
response = await agent.run(
        "What did the author do in college? Also, what's 7 * 8?"
    )
print(str(response))
# Out:
# 2026-03-12 16:45:25,533 - INFO - Loading all indices.
# 2026-03-12 16:45:28,733 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-12 16:45:29,655 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-03-12 16:45:30,984 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-03-12 16:45:31,743 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# In college, the author studied philosophy but found it boring, so he decided to switch to studying AI.
#
# Additionally, \( 7 \times 8 = 56 \).
